# %%
# Imports
from pathlib import Path

import torch

# Projektpfade
REPO_ROOT = Path.cwd().parents[2]
DATA_ROOT = REPO_ROOT / "data" / "icosimal_img_class_03" / "data_uniform_224_224_sets"
TRAIN_DIR = DATA_ROOT / "train"
VAL_DIR = DATA_ROOT / "validate"
OUTPUT_ROOT = REPO_ROOT / "outputs"
# Device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)

# Check
assert TRAIN_DIR.exists(), "Train folder fehlt, TRAIN_DIR ist: " + str(TRAIN_DIR)  # noqa: S101
assert VAL_DIR.exists(), "Validation folder fehlt VAL_DIR ist: " + str(VAL_DIR)  # noqa: S101
